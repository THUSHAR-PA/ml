# %%
import sys
# !{sys.executable} -m pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# ...

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\darks\anaconda3\envs\retail_analytics\python.exe

# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\darks\Downloads\ML_6_Month_Roadmap_Tracker_2(1).xlsx")
df
# Out:
#           Date  Week  Day             Category  \
# 0   2026-08-01   1.0  1.0  Python Fundamentals
# 1   2026-08-02   1.0  2.0  Python Fundamentals
# 2   2026-08-03   1.0  3.0  Python Fundamentals
# 3   2026-08-04   1.0  4.0            Algorithm
# 4   2026-08-04   1.0  4.0                  SQL
# ..         ...   ...  ...                  ...
# 175        NaT   NaN  NaN                  NaN
# 176        NaT   NaN  NaN                  NaN
# 177        NaT   NaN  NaN                  NaN
# 178        NaT   NaN  NaN                  NaN
# 179        NaT   NaN  NaN                  NaN
#
#                                           Topic / Task  \
# 0    Object-oriented Python basics (classes, methods).
# 1    Python libraries intro (NumPy arrays, basic ops).
# 2         Pandas introduction: DataFrames, reading CSV
# 3    Write\nrecursive and iterative functions for c...
# 4    Advanced SQL (GROUP BY, aggregations, subqueries)
# ..                                                 ...
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              17 non-null     datetime64[us]
#  1   Week              17 non-null     float64
#  2   Day               17 non-null     float64
#  3   Category          15 non-null     str
#  4   Topic / Task      15 non-null     str
#  5   Learning Outcome  10 non-null     str
#  6   Status            180 non-null    str
#  7   Priority          0 non-null      float64
#  8   Hours Planned     14 non-null     str
#  9   Hours Spent       2 non-null      str
#  10  Resources         13 non-null     str
#  11  Deliverable       14 non-null     str
#  12  Notes             2 non-null      str
#  13  Reviewed          2 non-null      str
#  14  Next Action       2 non-null      str
# dtypes: datetime64[us](1), float64(3), str(11)
# memory usage: 27.3 KB

# %%
df.shape
# Out:
# (180, 15)

# %%
df.tail()
# Out:
#     Date  Week  Day Category Topic / Task Learning Outcome       Status  \
# 175  NaT   NaN  NaN      NaN          NaN              NaN  Not Started
# 176  NaT   NaN  NaN      NaN          NaN              NaN  Not Started
# 177  NaT   NaN  NaN      NaN          NaN              NaN  Not Started
# 178  NaT   NaN  NaN      NaN          NaN              NaN  Not Started
# 179  NaT   NaN  NaN      NaN          NaN              NaN  Not Started
#
#      Priority Hours Planned Hours Spent Resources Deliverable Notes Reviewed  \
# 175       NaN           NaN         NaN       NaN         NaN   NaN      NaN
# 176       NaN           NaN         NaN       NaN         NaN   NaN      NaN
# 177       NaN           NaN         NaN       NaN         NaN   NaN      NaN
# 178       NaN           NaN         NaN       NaN         NaN   NaN      NaN
# 179       NaN           NaN         NaN       NaN         NaN   NaN      NaN
#
#     Next Action
# 175         NaN
# 176         NaN
# 177         NaN
# ...

# %%
df.head(10)
# Out:
#         Date  Week  Day                   Category  \
# 0 2026-08-01   1.0  1.0        Python Fundamentals
# 1 2026-08-02   1.0  2.0        Python Fundamentals
# 2 2026-08-03   1.0  3.0        Python Fundamentals
# 3 2026-08-04   1.0  4.0                  Algorithm
# 4 2026-08-04   1.0  4.0                        SQL
# 5 2026-08-05   1.0  5.0        Python Fundamentals
# 6 2026-08-06   1.0  6.0           review/reinforce
# 7 2026-08-07   1.0  7.0  ML Fundamentals & Statics
# 8 2026-08-08   2.0  1.0  ML Fundamentals & Statics
# 9 2026-08-09   2.0  2.0  ML Fundamentals & Statics
#
#                                         Topic / Task  \
# 0  Object-oriented Python basics (classes, methods).
# 1  Python libraries intro (NumPy arrays, basic ops).
# 2       Pandas introduction: DataFrames, reading CSV
# 3  Write\nrecursive and iterative functions for c...
# 4  Advanced SQL (GROUP BY, aggregations, subqueries)
# 5       : Basic OOP patterns in Python (inheritance)
# ...

# %%
df['Category']
# Out:
# 0                                    Python Fundamentals
# 1                                    Python Fundamentals
# 2                                    Python Fundamentals
# 3                                              Algorithm
# 4                                                    SQL
# 5                                    Python Fundamentals
# 6                                       review/reinforce
# 7                              ML Fundamentals & Statics
# 8                              ML Fundamentals & Statics
# 9                              ML Fundamentals & Statics
# 10                             ML Fundamentals & Statics
# 11                             ML Fundamentals & Statics
# 12     3 days left to understand weakness and improve...
# 13                                                   NaN
# 14                                                   NaN
# 15                                    Core ML Algorithms
# ...

# %%
df.loc[1:10]
# Out:
#          Date  Week  Day                   Category  \
# 1  2026-08-02   1.0  2.0        Python Fundamentals
# 2  2026-08-03   1.0  3.0        Python Fundamentals
# 3  2026-08-04   1.0  4.0                  Algorithm
# 4  2026-08-04   1.0  4.0                        SQL
# 5  2026-08-05   1.0  5.0        Python Fundamentals
# 6  2026-08-06   1.0  6.0           review/reinforce
# 7  2026-08-07   1.0  7.0  ML Fundamentals & Statics
# 8  2026-08-08   2.0  1.0  ML Fundamentals & Statics
# 9  2026-08-09   2.0  2.0  ML Fundamentals & Statics
# 10 2026-08-10   2.0  3.0  ML Fundamentals & Statics
#
#                                          Topic / Task  \
# 1   Python libraries intro (NumPy arrays, basic ops).
# 2        Pandas introduction: DataFrames, reading CSV
# 3   Write\nrecursive and iterative functions for c...
# 4   Advanced SQL (GROUP BY, aggregations, subqueries)
# 5        : Basic OOP patterns in Python (inheritance)
# 6                  Revisit tough Python/SQL problems.
# ...

# %% [markdown]
# # Filtering And Ordering

# %% [markdown]
# ## Filtering based on columns

# %%
df[df['Status'] == 'Completed']
# Out:
#         Date  Week  Day             Category  \
# 0 2026-08-01   1.0  1.0  Python Fundamentals
# 1 2026-08-02   1.0  2.0  Python Fundamentals
#
#                                         Topic / Task  \
# 0  Object-oriented Python basics (classes, methods).
# 1  Python libraries intro (NumPy arrays, basic ops).
#
#                          Learning Outcome     Status  Priority Hours Planned  \
# 0        To be familiarized in python oop  Completed       NaN           2hr
# 1  To be familiar in Python Library Numpy  Completed       NaN           4hr
#
#   Hours Spent                                         Resources  \
# 0         1hr  https://youtu.be/rLyYb7BFgQI?si=4rjWdFSmoYcEUIrI
# 1      2.5hrs  https://youtu.be/QUT1VHiLmmI?si=esVkANOrESh59ySI
#
#                                          Deliverable  \
# 0               Documented class examples on Github
# 1  Numpy array manipulations (slicing, linear alg...
#
#                                 Notes Reviewed  \
# ...

# %%
specific_columns = ["Python Fundamentals","SQL"]
df[df['Category'].isin(specific_columns)]
# Out:
#         Date  Week  Day             Category  \
# 0 2026-08-01   1.0  1.0  Python Fundamentals
# 1 2026-08-02   1.0  2.0  Python Fundamentals
# 2 2026-08-03   1.0  3.0  Python Fundamentals
# 4 2026-08-04   1.0  4.0                  SQL
# 5 2026-08-05   1.0  5.0  Python Fundamentals
#
#                                         Topic / Task  \
# 0  Object-oriented Python basics (classes, methods).
# 1  Python libraries intro (NumPy arrays, basic ops).
# 2       Pandas introduction: DataFrames, reading CSV
# 4  Advanced SQL (GROUP BY, aggregations, subqueries)
# 5       : Basic OOP patterns in Python (inheritance)
#
#                                     Learning Outcome       Status  Priority  \
# 0                   To be familiarized in python oop    Completed       NaN
# 1             To be familiar in Python Library Numpy    Completed       NaN
# 2                           To be familiar in pandas  Not Started       NaN
# ...

# %%
df[df['Category'].str.contains('ML')]
# Out:
#          Date  Week  Day                   Category  \
# 7  2026-08-07   1.0  7.0  ML Fundamentals & Statics
# 8  2026-08-08   2.0  1.0  ML Fundamentals & Statics
# 9  2026-08-09   2.0  2.0  ML Fundamentals & Statics
# 10 2026-08-10   2.0  3.0  ML Fundamentals & Statics
# 11 2026-08-11   2.0  4.0  ML Fundamentals & Statics
# 15 2026-08-15   3.0  1.0         Core ML Algorithms
# 16 2026-08-16   3.0  2.0         Core ML Algorithms
#
#                                          Topic / Task  \
# 7   Descriptive stats (mean, median, variance, dis...
# 8   Probability basics (Bayes’ rule, conditional p...
# 9         Central Limit Theorem, Confidence Intervals
# 10     Hypothesis testing basics (t-test, chi-square)
# 11  inear algebra refresh (vectors, matrices, dot ...
# 15                               Supervised learning
# 16                                     Classification
#
#                                      Learning Outcome       Status  Priority  \
# ...

# %%
df2 = df.set_index('Date')
df2
# Out:
#             Week  Day                                           Category  \
# Date
# 2026-08-01   1.0  1.0                                Python Fundamentals
# 2026-08-02   1.0  2.0                                Python Fundamentals
# 2026-08-03   1.0  3.0                                Python Fundamentals
# 2026-08-04   1.0  4.0                                          Algorithm
# 2026-08-04   1.0  4.0                                                SQL
# 2026-08-05   1.0  5.0                                Python Fundamentals
# 2026-08-06   1.0  6.0                                   review/reinforce
# 2026-08-07   1.0  7.0                          ML Fundamentals & Statics
# 2026-08-08   2.0  1.0                          ML Fundamentals & Statics
# 2026-08-09   2.0  2.0                          ML Fundamentals & Statics
# 2026-08-10   2.0  3.0                          ML Fundamentals & Statics
# 2026-08-11   2.0  4.0                          ML Fundamentals & Statics
# ...

# %%
df2.filter(items = ['Category', 'Status'], axis = 1)
# Out:
#                                                      Category       Status
# Date
# 2026-08-01                                Python Fundamentals    Completed
# 2026-08-02                                Python Fundamentals    Completed
# 2026-08-03                                Python Fundamentals  Not Started
# 2026-08-04                                          Algorithm  Not Started
# 2026-08-04                                                SQL  Not Started
# 2026-08-05                                Python Fundamentals  Not Started
# 2026-08-06                                   review/reinforce  Not Started
# 2026-08-07                          ML Fundamentals & Statics  Not Started
# 2026-08-08                          ML Fundamentals & Statics  Not Started
# 2026-08-09                          ML Fundamentals & Statics  Not Started
# 2026-08-10                          ML Fundamentals & Statics  Not Started
# ...

# %%
df2.filter(items = ["2026-08-01"], axis = 0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 df2.filter(items = ["2026-08-01"], axis = 0)
#
# File c:\Users\darks\anaconda3\envs\retail_analytics\Lib\site-packages\pandas\core\generic.py:5654, in NDFrame.filter(self, items, like, regex, axis)
#    5650             if len(items) == 0:
#    5651                 # Keep the dtype of labels when we are empty
#    5652                 items = items.astype(labels.dtype)
#    5653             # error: Keywords must be strings
# -> 5654             return self.reindex(**{name: items})  # type: ignore[misc]
#    5655         elif like:
#    5656
#    5657             def f(x) -> bool:
#
# File c:\Users\darks\anaconda3\envs\retail_analytics\Lib\site-packages\pandas\core\frame.py:6090, in DataFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
# ...

# %% [markdown]
# ## ORderby

# %%
df = pd.read_csv(r"C:\Users\darks\Downloads\world_population.csv")

# %%
df.head(2)
# Out:
#    Rank CCA3      Country Capital Continent  2022 Population  2020 Population  \
# 0    36  AFG  Afghanistan   Kabul      Asia       41128771.0       38972230.0
# 1   138  ALB      Albania  Tirana    Europe        2842321.0        2866849.0
#
#    2015 Population  2010 Population  2000 Population  1990 Population  \
# 0       33753499.0       28189672.0       19542982.0       10694796.0
# 1        2882481.0        2913399.0        3182021.0        3295066.0
#
#    1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# 0       12486631.0       10752971.0    652230.0            63.0587
# 1        2941651.0        2324731.0     28748.0            98.8702
#
#    Growth Rate  World Population Percentage
# 0       1.0257                         0.52
# 1       0.9957                         0.04

# %%
df[df['Rank'] < 10 ].sort_values(by = 'Rank', ascending = True)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
# 27      7  BRA         Brazil          Brasilia  South America
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 171     9  RUS         Russia            Moscow         Europe
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41      1.425887e+09     1.424930e+09     1.393715e+09     1.348191e+09
# 92      1.417173e+09     1.396387e+09     1.322867e+09     1.240614e+09
# 221     3.382899e+08     3.359420e+08     3.246078e+08     3.111828e+08
# ...

# %% [markdown]
# # Indexing

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\darks\Downloads\world_population.csv")
df.head(5)
# Out:
#    Rank CCA3         Country           Capital Continent  2022 Population  \
# 0    36  AFG     Afghanistan             Kabul      Asia       41128771.0
# 1   138  ALB         Albania            Tirana    Europe        2842321.0
# 2    34  DZA         Algeria           Algiers    Africa       44903225.0
# 3   213  ASM  American Samoa         Pago Pago   Oceania          44273.0
# 4   203  AND         Andorra  Andorra la Vella    Europe          79824.0
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0       38972230.0       33753499.0       28189672.0       19542982.0
# 1        2866849.0        2882481.0        2913399.0        3182021.0
# 2       43451666.0       39543154.0       35856344.0       30774621.0
# 3          46189.0          51368.0          54849.0          58230.0
# 4          77700.0          71746.0          71519.0          66097.0
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
df = pd.read_csv(r"C:\Users\darks\Downloads\world_population.csv", index_col = 'Country')
df.head(4)
# Out:
#                 Rank CCA3    Capital Continent  2022 Population  \
# Country
# Afghanistan       36  AFG      Kabul      Asia       41128771.0
# Albania          138  ALB     Tirana    Europe        2842321.0
# Algeria           34  DZA    Algiers    Africa       44903225.0
# American Samoa   213  ASM  Pago Pago   Oceania          44273.0
#
#                 2020 Population  2015 Population  2010 Population  \
# Country
# Afghanistan          38972230.0       33753499.0       28189672.0
# Albania               2866849.0        2882481.0        2913399.0
# Algeria              43451666.0       39543154.0       35856344.0
# American Samoa          46189.0          51368.0          54849.0
#
#                 2000 Population  1990 Population  1980 Population  \
# Country
# Afghanistan          19542982.0       10694796.0       12486631.0
# Albania               3182021.0        3295066.0        2941651.0
# Algeria              30774621.0       25518074.0       18739378.0
# ...

# %%
df.reset_index(inplace = True)
df.head(5)
# Out:
#           Country  Rank CCA3           Capital Continent  2022 Population  \
# 0     Afghanistan    36  AFG             Kabul      Asia       41128771.0
# 1         Albania   138  ALB            Tirana    Europe        2842321.0
# 2         Algeria    34  DZA           Algiers    Africa       44903225.0
# 3  American Samoa   213  ASM         Pago Pago   Oceania          44273.0
# 4         Andorra   203  AND  Andorra la Vella    Europe          79824.0
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0       38972230.0       33753499.0       28189672.0       19542982.0
# 1        2866849.0        2882481.0        2913399.0        3182021.0
# 2       43451666.0       39543154.0       35856344.0       30774621.0
# 3          46189.0          51368.0          54849.0          58230.0
# 4          77700.0          71746.0          71519.0          66097.0
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
df.set_index('Country', inplace = True)
df.head(5)
# Out:
#                 Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan       36  AFG             Kabul      Asia       41128771.0
# Albania          138  ALB            Tirana    Europe        2842321.0
# Algeria           34  DZA           Algiers    Africa       44903225.0
# American Samoa   213  ASM         Pago Pago   Oceania          44273.0
# Andorra          203  AND  Andorra la Vella    Europe          79824.0
#
#                 2020 Population  2015 Population  2010 Population  \
# Country
# Afghanistan          38972230.0       33753499.0       28189672.0
# Albania               2866849.0        2882481.0        2913399.0
# Algeria              43451666.0       39543154.0       35856344.0
# American Samoa          46189.0          51368.0          54849.0
# Andorra                 77700.0          71746.0          71519.0
#
#                 2000 Population  1990 Population  1980 Population  \
# Country
# ...

# %%
df.loc['Albania']
# Out:
# Rank                                 138
# CCA3                                 ALB
# Capital                           Tirana
# Continent                         Europe
# 2022 Population                2842321.0
# 2020 Population                2866849.0
# 2015 Population                2882481.0
# 2010 Population                2913399.0
# 2000 Population                3182021.0
# 1990 Population                3295066.0
# 1980 Population                2941651.0
# 1970 Population                2324731.0
# Area (km²)                       28748.0
# Density (per km²)                98.8702
# Growth Rate                       0.9957
# World Population Percentage         0.04
# Name: Albania, dtype: object

# %%
df.iloc[1]
# Out:
# Rank                                 138
# CCA3                                 ALB
# Capital                           Tirana
# Continent                         Europe
# 2022 Population                2842321.0
# 2020 Population                2866849.0
# 2015 Population                2882481.0
# 2010 Population                2913399.0
# 2000 Population                3182021.0
# 1990 Population                3295066.0
# 1980 Population                2941651.0
# 1970 Population                2324731.0
# Area (km²)                       28748.0
# Density (per km²)                98.8702
# Growth Rate                       0.9957
# World Population Percentage         0.04
# Name: Albania, dtype: object

# %% [markdown]
# ## MUlti_Indexing

# %%
df.reset_index(inplace = True)

# %%
df.head(10)
# Out:
#                Country      Continent  Rank CCA3           Capital  \
# 0          Afghanistan           Asia    36  AFG             Kabul
# 1              Albania         Europe   138  ALB            Tirana
# 2              Algeria         Africa    34  DZA           Algiers
# 3       American Samoa        Oceania   213  ASM         Pago Pago
# 4              Andorra         Europe   203  AND  Andorra la Vella
# 5               Angola         Africa    42  AGO            Luanda
# 6             Anguilla  North America   224  AIA        The Valley
# 7  Antigua and Barbuda  North America   201  ATG      Saint John’s
# 8            Argentina  South America    33  ARG      Buenos Aires
# 9              Armenia           Asia   140  ARM           Yerevan
#
#    2022 Population  2020 Population  2015 Population  2010 Population  \
# 0       41128771.0       38972230.0       33753499.0       28189672.0
# 1        2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
df.set_index(['Continent','Country'], inplace = True)
df.head(5)
# Out:
#                           Rank CCA3           Capital  2022 Population  \
# Continent Country
# Asia      Afghanistan       36  AFG             Kabul       41128771.0
# Europe    Albania          138  ALB            Tirana        2842321.0
# Africa    Algeria           34  DZA           Algiers       44903225.0
# Oceania   American Samoa   213  ASM         Pago Pago          44273.0
# Europe    Andorra          203  AND  Andorra la Vella          79824.0
#
#                           2020 Population  2015 Population  2010 Population  \
# Continent Country
# Asia      Afghanistan          38972230.0       33753499.0       28189672.0
# Europe    Albania               2866849.0        2882481.0        2913399.0
# Africa    Algeria              43451666.0       39543154.0       35856344.0
# Oceania   American Samoa          46189.0          51368.0          54849.0
# Europe    Andorra                 77700.0          71746.0          71519.0
#
# ...

# %%
df.sort_index(inplace = True)
df.head(10)
# Out:
#                                     Rank CCA3      Capital  2022 Population  \
# Continent Country
# Africa    Algeria                     34  DZA      Algiers       44903225.0
#           Angola                      42  AGO       Luanda       35588987.0
#           Benin                       77  BEN   Porto-Novo       13352864.0
#           Botswana                   144  BWA     Gaborone        2630296.0
#           Burkina Faso                58  BFA  Ouagadougou       22673762.0
#           Burundi                     78  BDI    Bujumbura       12889576.0
#           Cameroon                    53  CMR      Yaounde       27914536.0
#           Cape Verde                 171  CPV        Praia         593149.0
#           Central African Republic   117  CAF       Bangui        5579144.0
#           Chad                        69  TCD    N'Djamena       17723315.0
#
#                                     2020 Population  2015 Population  \
# Continent Country
# ...

# %%
df.loc['Asia']
## iloc cant do multi indexing
# Out:
#                       Rank CCA3              Capital  2022 Population  \
# Country
# Afghanistan             36  AFG                Kabul     4.112877e+07
# Armenia                140  ARM              Yerevan     2.780469e+06
# Azerbaijan              91  AZE                 Baku     1.035807e+07
# Bahrain                154  BHR               Manama     1.472233e+06
# Bangladesh               8  BGD                Dhaka     1.711864e+08
# Bhutan                 165  BTN              Thimphu     7.824550e+05
# Brunei                 175  BRN  Bandar Seri Begawan     4.490020e+05
# Cambodia                73  KHM           Phnom Penh     1.676784e+07
# China                    1  CHN              Beijing     1.425887e+09
# Georgia                131  GEO              Tbilisi     3.744385e+06
# Hong Kong              104  HKG            Hong Kong     7.488865e+06
# India                    2  IND            New Delhi     1.417173e+09
# ...
